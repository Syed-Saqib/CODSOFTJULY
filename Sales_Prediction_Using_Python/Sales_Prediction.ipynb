# %% [markdown]
# # Sales Prediction using Python

# %% [markdown]
# ## Importing the necessary libraries

# %%
# Import the numpy and pandas package
import numpy as np
import pandas as pd

# Data Visualisation
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Loading the dataset 
adv = pd.DataFrame(pd.read_csv("dataset/advertising.csv"))
adv.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
adv.shape
# Out:
# (200, 4)

# %%
adv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
adv.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# ## Cleaning the Data

# %% [markdown]
# #### Checking Null values

# %%
if(adv.isnull().values.any()):
    print("Null values present")
else:
    print("Null values not present")
# Out:
# Null values not present

# %% [markdown]
# #### Checking number of null values in each column.

# %%
adv.isnull().sum()*100/adv.shape[0]
# Out:
# TV           0.0
# Radio        0.0
# Newspaper    0.0
# Sales        0.0
# dtype: float64

# %% [markdown]
# #### Analysing the Outliers in dataset

# %%
fig, axs = plt.subplots(3, figsize = (5,5))
plt1 = sns.boxplot(adv['TV'], ax = axs[0])
plt2 = sns.boxplot(adv['Newspaper'], ax = axs[1])
plt3 = sns.boxplot(adv['Radio'], ax = axs[2])
plt.tight_layout()

# %%
# There are no considerable outliers present in the data.

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# #### Sales (Target Variable)

# %%
sns.boxplot(adv['Sales'])
plt.show()

# %% [markdown]
# #### Let's see how Sales are related with other variables using scatter plot.

# %%
sns.pairplot(adv, x_vars=['TV', 'Newspaper', 'Radio'], y_vars='Sales', height=4, aspect=1, kind='scatter')
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### Let's see the correlation between different variables.

# %%
sns.heatmap(adv.corr(), cmap="YlGnBu", annot = True)
plt.show()

# %% [markdown]
# ##### As it is visible from the pairplot and the heatmap, the variable `TV` seems to be most correlated with `Sales`. So let's go ahead and perform simple linear regression using `TV` as our feature variable.

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Performing Simple Linear Regression

# %% [markdown]
# Equation of linear regression<br>
# $y = c + m_1x_1 + m_2x_2 + ... + m_nx_n$
#
# -  $y$ is the response
# -  $c$ is the intercept
# -  $m_1$ is the coefficient for the first feature
# -  $m_n$ is the coefficient for the nth feature<br>
#
# In our case:
#
# $y = c + m_1 \times TV$
#
# The $m$ values are called the model **coefficients** or **model parameters**.
#
# ---

# %% [markdown]
# ### Generic Steps in model building using `statsmodels`
#
# We first assign the feature variable, `TV`, in this case, to the variable `X` and the response variable, `Sales`, to the variable `y`.

# %%
X = adv['TV']
y = adv['Sales']

# %% [markdown]
# #### Train-Test Split
#
# We now need to split our variable into training and testing sets. We will perform this by importing `train_test_split` from the `sklearn.model_selection` library.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, test_size = 0.3, random_state = 100)

# %% [markdown]
# ##### Let's now take a look at the train dataset

# %%
X_train.head()
# Out:
# 74     213.4
# 3      151.5
# 185    205.0
# 26     142.9
# 90     134.3
# Name: TV, dtype: float64

# %%
y_train.head()
# Out:
# 74     17.0
# 3      16.5
# 185    22.6
# 26     15.0
# 90     14.0
# Name: Sales, dtype: float64

# %% [markdown]
# #### Building a Linear Model
#
# We first need to import the `statsmodel.api` library using which we will perform the Linear Regression.

# %%
import statsmodels.api as sm

# %% [markdown]
# By default, the `statsmodels` library fits a line on the dataset which passes through the origin. But in order to have an intercept, we need to manually use the `add_constant` attribute of `statsmodels`. And once we've added the constant to your `X_train` dataset, we can go ahead and fit a regression line using the `OLS` (Ordinary Least Squares) attribute of `statsmodels` as shown below

# %% [markdown]
# ##### Add a constant to get an intercept

# %%
X_train_sm = sm.add_constant(X_train)

# %% [markdown]
# ##### Fit the resgression line using 'OLS'

# %%
lr = sm.OLS(y_train, X_train_sm).fit()

# %% [markdown]
# ##### Printing the parameters, i.e. the intercept and the slope of the regression line fitted

# %%
lr.params
# Out:
# const    6.948683
# TV       0.054546
# dtype: float64

# %% [markdown]
# ##### Performing a summary operation lists out all the different parameters of the regression line fitted

# %%
print(lr.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.816
# Model:                            OLS   Adj. R-squared:                  0.814
# Method:                 Least Squares   F-statistic:                     611.2
# Date:                Sat, 22 Jul 2023   Prob (F-statistic):           1.52e-52
# Time:                        20:37:11   Log-Likelihood:                -321.12
# No. Observations:                 140   AIC:                             646.2
# Df Residuals:                     138   BIC:                             652.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.9487      0.385     18.068      0.000       6.188       7.709
# ...

# %% [markdown]
# ####  Looking at some key statistics from the summary

# %% [markdown]
# The values we are concerned with are -
# 1. The coefficients and significance (p-values)
# 2. R-squared
# 3. F statistic and its significance

# %% [markdown]
# ##### 1. The coefficient for TV is 0.054, with a very low p value
# The coefficient is statistically significant. So the association is not purely by chance.

# %% [markdown]
# ##### 2. R - squared is 0.816
# Meaning that 81.6% of the variance in `Sales` is explained by `TV`
#
# This is a decent R-squared value.

# %% [markdown]
# ##### 3. F statistic has a very low p value (practically low)
# Meaning that the model fit is statistically significant, and the explained variance isn't purely by chance.

# %% [markdown]
# ---
# The fit is significant. Let's visualize how well the model fit the data.
#
# From the parameters that we get, our linear regression equation becomes:
#
# $ Sales = 6.948 + 0.054 \times TV $

# %%
plt.scatter(X_train, y_train)
plt.plot(X_train, 6.948 + 0.054*X_train, 'r')
plt.show()

# %% [markdown]
# ## Evaluating the Model

# %% [markdown]
# ### Residual analysis
# Residual analysis is performed to verify the assumptions made by the model and, consequently, assess the reliability of the inferences it provides.

# %% [markdown]
# #### Distribution of the error terms
# To ensure one of the fundamental assumptions of linear regression is met, which is the normal distribution of error terms, we will create a histogram to visualize the distribution of these error terms. This will help us assess whether the errors follow a normal distribution or not.

# %%
y_train_pred = lr.predict(X_train_sm)
res = (y_train - y_train_pred)

# %%
fig = plt.figure()
sns.displot(res, bins = 15)
fig.suptitle('Error Terms', fontsize = 15)                  # Plot heading 
plt.xlabel('y_train - y_train_pred', fontsize = 15)         # X-label
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# The residuals are following the normally distributed with a mean 0. All good!

# %% [markdown]
# #### Looking for patterns in the residuals

# %%
plt.scatter(X_train,res)
plt.show()

# %% [markdown]
# We have established with confidence that the model's fit is not a result of chance and demonstrates reasonable predictive capability. The normality of the residual terms enables us to make inferences about the coefficients.
#
# However, it is important to note that the variance of residuals increases with X, indicating substantial variation that the current model cannot account for or explain adequately.

# %% [markdown]
# As you can see, the regression line is a pretty good fit to the data

# %% [markdown]
# ### Predictions on the Test Set

# %% [markdown]
# Now that you have fitted a regression line on your train dataset, it's time to make some predictions on the test data. For this, you first need to add a constant to the `X_test` data like you did for `X_train` and then you can simply go on and predict the y values corresponding to `X_test` using the `predict` attribute of the fitted regression line.

# %%
# Add a constant to X_test
X_test_sm = sm.add_constant(X_test)

# Predict the y values corresponding to X_test_sm
y_pred = lr.predict(X_test_sm)

# %%
y_pred.head()
# Out:
# 126     7.374140
# 104    19.941482
# 99     14.323269
# 92     18.823294
# 111    20.132392
# dtype: float64

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %% [markdown]
# ##### Looking at the RMSE

# %%
#Returns the mean squared error; we'll take a square root
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 2.019296008966232

# %% [markdown]
# ##### Checking the R-squared on the test set

# %%
r_squared = r2_score(y_test, y_pred)
r_squared
# Out:
# 0.792103160124566

# %% [markdown]
# ##### Visualizing the fit on the test set

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test, 6.948 + 0.054 * X_test, 'r')
plt.show()
